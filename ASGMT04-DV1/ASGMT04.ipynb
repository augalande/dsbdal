# %% [raw]
# Data Visualization I
# Use the inbuilt dataset 'titanic'. The dataset contains 891 rows and contains information about the passengers who boarded the unfortunate Titanic ship. Use the Seaborn library to see if we can find any patterns in the data.
# Write a code to check how the price of the ticket (column name: 'fare') for each passenger is distributed by plotting a histogram.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df=df.astype({"Name":"string","Sex":"string","Ticket":"string","Cabin":"string","Embarked":"string"})

# %%
df.dtypes
# Out:
# PassengerId             int64
# Survived                int64
# Pclass                  int64
# Name           string[python]
# Sex            string[python]
# Age                   float64
# SibSp                   int64
# Parch                   int64
# Ticket         string[python]
# Fare                  float64
# Cabin          string[python]
# Embarked       string[python]
# dtype: object

# %%
df["Age"].fillna(df["Age"].median(),inplace=True)

# %%
df["Fare"].fillna(df["Fare"].median(),inplace=True)

# %%
df.fillna("Not Available",inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Pclass vs Survived
sns.countplot(data=df,x="Pclass",hue="Survived")
#First Class passenger were saved the most and Third Class Passengers died the most
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.histplot(data=df,x="Sex",bins=2)
#more male passengers travelled than female
# Out:
# <Axes: xlabel='Sex', ylabel='Count'>

# %%
#Sex(Survived)
sns.countplot(data=df,x="Sex",hue="Survived")
#Males died the most and Females survived the most
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
#Age Histplot:- More people from age 25-30
sns.histplot(data=df,x="Age",bins=20)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(data=df,x="Fare",bins=20)
#Maximum tickets were sold below 25
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
sns.histplot(data=df,x="Embarked",bins=20)
#Maximum people embarked at S
# Out:
# <Axes: xlabel='Embarked', ylabel='Count'>

# %%
#embarked vs survived
# more people which were embarked at S did not survive
sns.countplot(data=df,x="Embarked",hue="Survived")
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
sns.histplot(data=df,x="Age",bins=10)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(data=df,x="Fare",bins=10)
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
sns.boxplot(data=df,x="Survived",y="Age")
#Younger People survied
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
#fare vs survived
sns.boxplot(data=df,x="Survived",y="Fare")
# People with fare price higher survied more
# Out:
# <Axes: xlabel='Survived', ylabel='Fare'>

# %%
sns.boxplot(data=df,x="Pclass",y="Age")
#Elder people were travelling in First Class wereas younger one were travelling in 3 class
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.boxplot(data=df,x="Pclass",y="Fare")
#First class tickets were expensive than Thrid class tickets
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
#Pclass vs Age
sns.countplot(data=df,x="Pclass",hue="Survived")
#more deaths in class 3 where as less deaths in class 1
#already done
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(data=df,x="SibSp",hue="Survived")
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %%
sns.histplot(data=df,x="SibSp",bins=16)
# Out:
# <Axes: xlabel='SibSp', ylabel='Count'>

# %%
sns.countplot(data=df,x="Parch",hue="Survived")
# Out:
# <Axes: xlabel='Parch', ylabel='count'>

# %%
sns.histplot(data=df,x="Parch",bins=16)
# Out:
# <Axes: xlabel='Parch', ylabel='Count'>

# %%
sns.barplot(x='Pclass', y='Survived', data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
sns.barplot(x='Sex', y='Fare', data=df)
#female paid more fare as compared to males
# Out:
# <Axes: xlabel='Sex', ylabel='Fare'>

# %%
sns.scatterplot(x='Age', y='Fare', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
df.drop("Name",axis=1,inplace=True)
df.drop("Sex",axis=1,inplace=True)
df.drop("Cabin",axis=1,inplace=True)
df.drop("Embarked",axis=1,inplace=True)
df.drop("Ticket",axis=1,inplace=True)

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >
