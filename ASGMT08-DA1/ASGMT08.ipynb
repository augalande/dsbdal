# %% [raw]
# Data Analytics I
# Create a Linear Regression Model using Python/R to predict home prices using Boston Housing Dataset (https://www.kaggle.com/c/boston-housing). The Boston Housing dataset contains information about various houses in Boston through different parameters. There are 506 samples and 14 feature variables in this dataset.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("boston_housing.csv")

# %%
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
df.dtypes
# Out:
# crim       float64
# zn         float64
# indus      float64
# chas         int64
# nox        float64
# rm         float64
# age        float64
# dis        float64
# rad          int64
# tax          int64
# ptratio    float64
# b          float64
# lstat      float64
# medv       float64
# dtype: object

# %%
df.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %% [raw]
# EDA(Exploratory Data Analysis)
# 1)Summary Analysis

# %%
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             lstat        medv
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
sns.boxplot(data=df)
# Out:
# <Axes: >

# %% [raw]
# Corrletaional Analysis

# %%
df.corr()
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# b       -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069 -0.273534
# lstat    0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.613808  0.602339
# medv    -0.388305  0.360445 -0.483725  0.175260 -0.427321  0.695360 -0.376955
#
#               dis       rad       tax   ptratio         b     lstat      medv
# crim    -0.379670  0.625505  0.582764  0.289946 -0.385064  0.455621 -0.388305
# zn       0.664408 -0.311948 -0.314563 -0.391679  0.175520 -0.412995  0.360445
# indus   -0.708027  0.595129  0.720760  0.383248 -0.356977  0.603800 -0.483725
# chas    -0.099176 -0.007368 -0.035587 -0.121515  0.048788 -0.053929  0.175260
# nox     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.590879 -0.427321
# rm       0.205246 -0.209847 -0.292048 -0.355501  0.128069 -0.613808  0.695360
# age     -0.747881  0.456022  0.506456  0.261515 -0.273534  0.602339 -0.376955
# dis      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.496996  0.249929
# rad     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.488676 -0.381626
# tax     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.543993 -0.468536
# ptratio -0.232471  0.464741  0.460853  1.000000 -0.177383  0.374044 -0.507787
# b        0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.366087  0.333461
# lstat   -0.496996  0.488676  0.543993  0.374044 -0.366087  1.000000 -0.737663
# medv     0.249929 -0.381626 -0.468536 -0.507787  0.333461 -0.737663  1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
df.skew()
# Out:
# crim       5.223149
# zn         2.225666
# indus      0.295022
# chas       3.405904
# nox        0.729308
# rm         0.403612
# age       -0.598963
# dis        1.011781
# rad        1.004815
# tax        0.669956
# ptratio   -0.802325
# b         -2.890374
# lstat      0.906460
# medv       1.108098
# dtype: float64

# %% [raw]
# Outlier Removal

# %%
def remove_outliers(name:str):
    global df
    q3,q1=np.percentile(df[name],[75,25])
    iqr=q3-q1
    df=df[ (df[name]>=q1-(1.5*iqr)) & (df[name]<=q3+(1.5*iqr)) ]
remove_outliers("crim")
remove_outliers("zn")
remove_outliers("chas")
remove_outliers("rm")
remove_outliers("dis")
remove_outliers("ptratio")
remove_outliers("b")
remove_outliers("lstat")
remove_outliers("medv")

# %%
df.describe()
# Out:
#              crim          zn       indus   chas         nox          rm  \
# count  260.000000  260.000000  260.000000  260.0  260.000000  260.000000
# mean     0.965998    5.713462   10.317423    0.0    0.526242    6.190877
# std      1.929313   11.454106    6.167100    0.0    0.089140    0.387048
# min      0.006320    0.000000    1.250000    0.0    0.409000    4.973000
# 25%      0.082382    0.000000    5.860000    0.0    0.449000    5.926750
# 50%      0.160735    0.000000    8.140000    0.0    0.515000    6.148000
# 75%      0.518123    0.000000   13.920000    0.0    0.573000    6.434000
# max      8.716750   45.000000   27.740000    0.0    0.871000    7.412000
#
#               age         dis         rad         tax     ptratio           b  \
# count  260.000000  260.000000  260.000000  260.000000  260.000000  260.000000
# mean    63.893846    4.118123    7.053846  364.823077   18.859615  389.608154
# std     26.744482    1.766543    6.752447  138.375432    1.699223   10.031401
# min      2.900000    1.525700    1.000000  188.000000   14.700000  350.450000
# 25%     42.375000    2.588850    4.000000  281.000000   17.800000  386.932500
# 50%     68.450000    3.822600    5.000000  307.000000   19.100000  393.655000
# 75%     88.100000    5.400700    6.000000  403.000000   20.200000  396.900000
# max    100.000000    8.906700   24.000000  711.000000   21.200000  396.900000
#
#             lstat        medv
# count  260.000000  260.000000
# mean    11.332115   21.446154
# std      4.450409    4.173434
# min      2.980000   11.500000
# 25%      7.722500   18.900000
# 50%     10.545000   21.200000
# 75%     14.285000   23.825000
# max     24.560000   32.000000

# %%
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
df.skew()
# Out:
# crim       2.514545
# zn         1.810073
# indus      0.916981
# chas       0.000000
# nox        1.278399
# rm         0.353010
# age       -0.442731
# dis        0.630565
# rad        1.989188
# tax        1.328032
# ptratio   -0.585832
# b         -1.950513
# lstat      0.507182
# medv       0.205213
# dtype: float64

# %% [raw]
# Model Creation

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

x=df[['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
       'ptratio', 'b', 'lstat']]
y=df["medv"]

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)
model=LinearRegression().fit(x_train,y_train)
y_pred=model.predict(x_test)

# %%
x_train
# Out:
#         crim   zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 318  0.40202  0.0   9.90     0  0.544  6.382  67.2  3.5325    4  304     18.4
# 359  4.26131  0.0  18.10     0  0.770  6.112  81.3  2.5091   24  666     20.2
# 499  0.17783  0.0   9.69     0  0.585  5.569  73.5  2.3999    6  391     19.2
# 78   0.05646  0.0  12.83     0  0.437  6.232  53.7  5.0141    5  398     18.7
# 117  0.15098  0.0  10.01     0  0.547  6.021  82.6  2.7474    6  432     17.8
# ..       ...  ...    ...   ...    ...    ...   ...     ...  ...  ...      ...
# 227  0.41238  0.0   6.20     0  0.504  7.163  79.9  3.2157    8  307     17.4
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 91   0.03932  0.0   3.41     0  0.489  6.405  73.9  3.0921    2  270     17.8
# 476  4.87141  0.0  18.10     0  0.614  6.484  93.6  2.3053   24  666     20.2
# 49   0.21977  0.0   6.91     0  0.448  5.602  62.0  6.0877    3  233     17.9
#
#           b  lstat
# 318  395.21  10.36
# 359  390.74  12.67
# 499  395.77  15.10
# 78   386.40  12.34
# 117  394.51  10.30
# ..      ...    ...
# 227  372.08   6.36
# 501  391.99   9.67
# 91   393.55   8.20
# 476  396.21  18.68
# 49   396.90  16.20
#
# [182 rows x 13 columns]

# %%
x_test
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 129  0.88125   0.0  21.89     0  0.624  5.637  94.7  1.9799    4  437
# 491  0.10574   0.0  27.74     0  0.609  5.983  98.8  1.8681    4  711
# 330  0.04544   0.0   3.24     0  0.460  6.144  32.2  5.8736    4  430
# 164  2.24236   0.0  19.58     0  0.605  5.854  91.8  2.4220    5  403
# 326  0.30347   0.0   7.38     0  0.493  6.312  28.9  5.4159    5  287
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 492  0.11132   0.0  27.74     0  0.609  5.983  83.5  2.1099    4  711
# 88   0.05660   0.0   3.41     0  0.489  7.007  86.3  3.4217    2  270
# 346  0.06162   0.0   4.39     0  0.442  5.898  52.3  8.0136    3  352
# 140  0.29090   0.0  21.89     0  0.624  6.174  93.6  1.6119    4  437
# 270  0.29916  20.0   6.96     0  0.464  5.856  42.1  4.4290    3  223
#
#      ptratio       b  lstat
# 129     21.2  396.90  18.34
# 491     20.1  390.11  18.07
# 330     16.9  368.57   9.09
# 164     14.7  395.11  11.64
# 326     19.6  396.90   6.15
# ..       ...     ...    ...
# 492     20.1  396.90  13.35
# 88      17.8  396.90   5.50
# 346     18.8  364.61  12.67
# 140     21.2  388.08  24.16
# 270     18.6  388.65  13.00
#
# [78 rows x 13 columns]

# %%
y_train
# Out:
# 318    23.1
# 359    22.6
# 499    17.5
# 78     21.2
# 117    19.2
#        ...
# 227    31.6
# 501    22.4
# 91     22.0
# 476    16.7
# 49     19.4
# Name: medv, Length: 182, dtype: float64

# %%
y_test
# Out:
# 129    14.3
# 491    13.6
# 330    19.8
# 164    22.7
# 326    23.0
#        ...
# 492    20.1
# 88     23.6
# 346    17.2
# 140    14.0
# 270    21.1
# Name: medv, Length: 78, dtype: float64

# %%
y_pred
# Out:
# array([14.60427693, 14.49947677, 21.67575311, 20.33093345, 23.92345525,
#        16.63684264, 23.26221819, 25.24835748, 28.6037476 , 17.5546282 ,
#        21.44022007, 21.21471765, 22.19937356, 21.14038134, 24.35878573,
#        19.20983051, 18.44578055, 24.95072994, 25.75235028, 22.34088342,
#        18.47077879, 29.74709744, 24.15015679, 18.64741541, 20.63042978,
#        18.86704925, 21.27425011, 21.2405065 , 25.74522113, 19.27895588,
#        16.49810229, 21.04103239, 20.33323166, 22.15639739, 19.43859497,
#        21.7001149 , 24.13869486, 21.75990974, 24.4014171 , 20.87106756,
#        19.14169046, 20.15938995, 18.73713917, 17.5908324 , 24.87237607,
#        14.24506828, 25.67677176, 28.62921269, 24.49021569, 16.07410254,
#        24.06155965, 22.4766677 , 22.21332001, 29.18003797, 22.87105989,
#        20.15871853, 19.7660756 , 22.79436333, 26.31215422, 27.50085068,
#        24.30394593, 19.60046617, 23.94691852, 20.70525261, 21.28606428,
#        22.59642514, 17.49856595, 24.63059673, 21.40886679, 23.55638976,
#        21.10087545, 26.26997922, 22.84693176, 16.4984739 , 26.68126098,
#        16.7913786 , 15.04879223, 21.13745677])

# %%
#Testing 
from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
r2=r2_score(y_test,y_pred)
print(mse)
print(rmse)
print(r2)
# Out:
# 5.966979582113376
# 2.442740179002543
# 0.6473809562990076

# %%
model.score(x_train,y_train)
# Out:
# 0.755246812888726

# %%
model.score(x_test,y_test)
# Out:
# 0.6473809562990076

# %%
import matplotlib.pyplot as plt
sns.scatterplot(x=y_test,y=y_pred)
ideal_values=np.linspace(min(y_test),max(y_test))
plt.plot(ideal_values,ideal_values,color="red")
plt.xlabel("Acutal Price in $1000")
plt.ylabel("Predicted Price in $1000")
plt.title("Linear Regression")
plt.show()
